# %% [markdown]
# # ENTREGA PRACTICA 2
# ## 10. Simulación de partidas y ranking en shooter online
# Simule varias partidas de un juego de disparos y genere un ranking basado en el puntaje
# total de cada jugador. Se utilizará el siguiente sistema de puntuación:

# %%
import sys
import os

sys.path.append(os.path.abspath("../")) 

#defino el sistema de puntuacion
pt_kill=3
pt_asistencia = 1
pt_muerte = -1

#defino la estructura para el conteo del puntaje asignando a cada jugador el puntaje inicial en 0,


score_players = {
'Shadow': {'kills': 0, 'assists': 0, 'deaths': 0 , 'MPV':0 , 'pt_final':0},
'Blaze': {'kills': 0, 'assists': 0, 'deaths': 0, 'MPV':0 , 'pt_final':0},
'Viper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MPV':0 , 'pt_final':0},
'Frost': {'kills': 0, 'assists': 0, 'deaths': 0, 'MPV':0 , 'pt_final':0},
'Reaper': {'kills': 0, 'assists': 0, 'deaths': 0, 'MPV':0 , 'pt_final':0},
}


rounds = [
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': True},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': False},
'Viper': {'kills': 1, 'assists': 2, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 0, 'assists': 2, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 0, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': False},
'Frost': {'kills': 2, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 0, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 0, 'deaths': False},
'Blaze': {'kills': 2, 'assists': 2, 'deaths': True},
'Viper': {'kills': 1, 'assists': 1, 'deaths': True},
'Frost': {'kills': 0, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 2, 'assists': 1, 'deaths': False},
'Blaze': {'kills': 1, 'assists': 0, 'deaths': True},
'Viper': {'kills': 0, 'assists': 2, 'deaths': False},
'Frost': {'kills': 1, 'assists': 1, 'deaths': True},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': False}
},
{
'Shadow': {'kills': 1, 'assists': 2, 'deaths': True},
'Blaze': {'kills': 0, 'assists': 1, 'deaths': False},
'Viper': {'kills': 2, 'assists': 0, 'deaths': True},
'Frost': {'kills': 1, 'assists': 1, 'deaths': False},
'Reaper': {'kills': 1, 'assists': 1, 'deaths': True}
}
]

round_number =0

for round in rounds:
    #defino la variable para contabilizar cada ronda
    round_number+=1
    print( f"Ranking ronda {round_number}:")
   
    this_round = {"Shadow":0,"Blaze":0 ,"Viper":0,"Frost":0,"Reaper":0}
    for player in round:
        
       
        # tomo el puntaje de cada jugador para la ronda actual
        score_ind = round[player]

        #calculo el puntaje total de cada jugados en este ronda

        this_round[player]= score_ind['kills'] *pt_kill + score_ind['assists']*pt_asistencia + score_ind['deaths']* pt_muerte

        # actualizo los totales generales

        score_players[player]['kills'] += score_ind['kills']
        score_players[player]['assists'] += score_ind['assists']
        score_players[player]['deaths'] += score_ind['deaths']

       
        #sumo al puntaje final lo obtenido en esta ronda  cada jugador
        score_players[player]['pt_final'] +=  this_round[player]

     

    ## defino el ganador de la ronda
    winner = max(this_round, key=this_round.get)

    ranking_round = dict(sorted(score_players.items(), key=lambda item: item[1]['pt_final'],reverse=True))

    print("{0} {1} {2} {3} {4}".format('Jugador','Kills','Asistencias','Muertes','Puntos'))

    for elem in ranking_round:
        print(f"{elem:<8}{ranking_round[elem]['kills']:<6}{ranking_round[elem]['assists']:<12}{ranking_round[elem]['deaths']:<8}{ranking_round[elem]['pt_final']:<8}")



    print(f"El ganador de la ronda {round_number} es: {winner} con {this_round[winner]} puntos.\n")
  
    score_players[winner]['MPV']+=1
    #se muestra el resultado final

 #muestro resultado final
ranking_final = dict(sorted(score_players.items(), key=lambda item: item[1]['pt_final'],reverse=True))
 
print("{0} {1} {2} {3} {4} {5} ".format('Jugador','Kills','Asistencias','Muertes','MPVs','Puntos'))
for elem in ranking_final:
    print(f"{elem:<8}{ranking_final[elem]['kills']:<6}{ranking_final[elem]['assists']:<12}{ranking_final[elem]['deaths']:<8}{ranking_final[elem]['MPV']:<5}{ranking_final[elem]['pt_final']}")
# Out:
# Ranking ronda 1:
# Jugador Kills Asistencias Muertes Puntos
# Shadow  2     1           1       6
# Viper   1     2           1       4
# Reaper  1     1           0       4
# Blaze   1     0           0       3
# Frost   0     1           0       1
# El ganador de la ronda 1 es: Shadow con 6 puntos.
#
# Ranking ronda 2:
# Jugador Kills Asistencias Muertes Puntos
# Shadow  2     3           1       8
# Blaze   3     0           1       8
# Viper   2     3           1       8
# Frost   2     2           1       7
# Reaper  1     2           0       5
# El ganador de la ronda 2 es: Frost con 6 puntos.
#
# Ranking ronda 3:
# Jugador Kills Asistencias Muertes Puntos
# Blaze   5     2           2       15
# Shadow  3     3           1       11
# Viper   3     4           2       11
# Reaper  2     3           0       9
# Frost   2     3           1       8
# El ganador de la ronda 3 es: Blaze con 7 puntos.
#
# Ranking ronda 4:
# Jugador Kills Asistencias Muertes Puntos
# ...
